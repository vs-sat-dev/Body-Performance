# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bodyPerformanceI.csv')
df
# Out:
#        age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     24.0      F      152.4       42.5        23.4       57.0     112.0
# 1     27.0      F      162.1       70.9        35.7       97.0     148.0
# 2     23.0      M      173.7       68.3        13.6       76.0     137.0
# 3     31.0      M      168.2       70.5        15.5       82.0     145.0
# 4     25.0      M      175.1       64.8         6.9       65.0     118.0
# ...    ...    ...        ...        ...         ...        ...       ...
# 7010  21.0      M      179.6       78.6        16.3       64.0     118.0
# 7011  56.0      M      166.8       64.0        21.4       75.0     132.0
# 7012  26.0      M      177.4       78.3        14.0       74.0     115.0
# 7013  49.0      M      177.2       83.0        19.7       98.0     158.0
# 7014  43.0      F      161.5       49.9        29.8       79.0     155.0
#
#       gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7015 entries, 0 to 7014
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      7015 non-null   float64
#  1   gender                   7015 non-null   object
#  2   height_cm                7015 non-null   float64
#  3   weight_kg                7015 non-null   float64
#  4   body fat_%               7015 non-null   float64
#  5   diastolic                7015 non-null   float64
#  6   systolic                 7015 non-null   float64
#  7   gripForce                7015 non-null   float64
#  8   sit and bend forward_cm  7015 non-null   float64
#  9   sit-ups counts           7015 non-null   float64
#  10  broad jump_cm            7015 non-null   float64
#  11  class                    7015 non-null   object
# dtypes: float64(10), object(2)
# memory usage: 657.8+ KB

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# M    4552
# F    2463
# Name: gender, dtype: int64

# %%
df['class'].value_counts()
# Out:
# B    3222
# C    2565
# A     617
# D     611
# Name: class, dtype: int64

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        fig, ax = plt.subplots(figsize=(12, 6))
        ax = sns.histplot(data=df[column])
        ax.set_title(column)
    elif df[column].dtype == 'float64':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))
        sns.boxplot(data=df[column], ax=ax[0])
        ax[0].set_title(column)
        
        sns.distplot(x=df[column], ax=ax[1]);
        ax[1].set_title(column)

# %%
new_df = df.copy()
new_df['gender'] = df['gender'].replace({'M': 0, 'F': 1})
new_df['class'] =  df['class'].replace({'A': 0, 'B': 1, 'C': 2, 'D': 3})
new_df
# Out:
#        age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     24.0       1      152.4       42.5        23.4       57.0     112.0
# 1     27.0       1      162.1       70.9        35.7       97.0     148.0
# 2     23.0       0      173.7       68.3        13.6       76.0     137.0
# 3     31.0       0      168.2       70.5        15.5       82.0     145.0
# 4     25.0       0      175.1       64.8         6.9       65.0     118.0
# ...    ...     ...        ...        ...         ...        ...       ...
# 7010  21.0       0      179.6       78.6        16.3       64.0     118.0
# 7011  56.0       0      166.8       64.0        21.4       75.0     132.0
# 7012  26.0       0      177.4       78.3        14.0       74.0     115.0
# 7013  49.0       0      177.2       83.0        19.7       98.0     158.0
# 7014  43.0       1      161.5       49.9        29.8       79.0     155.0
#
#       gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  class
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(new_df.corr(), ax=ax, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = new_df.corr()
unstacked = corr.unstack()
for e, u in enumerate(unstacked):
    if u == 1:
        unstacked[e] = 0

# %%
#Max absolute correlation
unstacked.abs().sort_values(ascending=False)
# Out:
# gender      gripForce     0.811698
# gripForce   gender        0.811698
# weight_kg   height_cm     0.761105
# height_cm   weight_kg     0.761105
# weight_kg   gripForce     0.752092
#                             ...
# body fat_%  body fat_%    0.000000
# weight_kg   weight_kg     0.000000
# height_cm   height_cm     0.000000
# gender      gender        0.000000
# class       class         0.000000
# Length: 144, dtype: float64

# %%
#Max positive correlation
unstacked.sort_values(ascending=False)
# Out:
# weight_kg       height_cm        0.761105
# height_cm       weight_kg        0.761105
# weight_kg       gripForce        0.752092
# gripForce       weight_kg        0.752092
# sit-ups counts  broad jump_cm    0.740434
#                                    ...
# height_cm       gender          -0.723391
# broad jump_cm   gender          -0.727814
# gender          broad jump_cm   -0.727814
#                 gripForce       -0.811698
# gripForce       gender          -0.811698
# Length: 144, dtype: float64

# %%
#Max negative correlation
unstacked.sort_values(ascending=True)
# Out:
# gripForce      gender           -0.811698
# gender         gripForce        -0.811698
#                broad jump_cm    -0.727814
# broad jump_cm  gender           -0.727814
# height_cm      gender           -0.723391
#                                    ...
# broad jump_cm  sit-ups counts    0.740434
# weight_kg      gripForce         0.752092
# gripForce      weight_kg         0.752092
# weight_kg      height_cm         0.761105
# height_cm      weight_kg         0.761105
# Length: 144, dtype: float64

# %%
# Max absolute correlation for target feature class
corr.loc[corr.index == 'class'].abs().max().sort_values(ascending=False)[1:]
# Out:
# sit and bend forward_cm    0.459989
# sit-ups counts             0.317935
# body fat_%                 0.216034
# broad jump_cm              0.180268
# weight_kg                  0.122481
# gripForce                  0.100442
# gender                     0.049443
# diastolic                  0.037550
# height_cm                  0.031961
# age                        0.024815
# systolic                   0.019069
# dtype: float64

# %%
# Max positive correlation for target feature class
corr.loc[corr.index == 'class'].max().sort_values(ascending=False)[1:]
# Out:
# body fat_%                 0.216034
# weight_kg                  0.122481
# diastolic                  0.037550
# height_cm                  0.031961
# age                        0.024815
# systolic                   0.019069
# gender                    -0.049443
# gripForce                 -0.100442
# broad jump_cm             -0.180268
# sit-ups counts            -0.317935
# sit and bend forward_cm   -0.459989
# dtype: float64

# %%
# Max negative correlation for target feature class
corr.loc[corr.index == 'class'].min().sort_values(ascending=True)
# Out:
# sit and bend forward_cm   -0.459989
# sit-ups counts            -0.317935
# broad jump_cm             -0.180268
# gripForce                 -0.100442
# gender                    -0.049443
# systolic                   0.019069
# age                        0.024815
# height_cm                  0.031961
# diastolic                  0.037550
# weight_kg                  0.122481
# body fat_%                 0.216034
# class                      1.000000
# dtype: float64

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import (accuracy_score, confusion_matrix, 
                             classification_report, f1_score,
                             precision_score, recall_score, roc_auc_score)
from xgboost import XGBClassifier
from xgboost import plot_importance
import numpy as np

# %%
def xgb_run(data):
    full_preds = np.zeros(len(data))
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        x_train, y_train = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        x_val, y_val = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']

        model = XGBClassifier(silent=True, verbosity=0)
        model.fit(x_train, y_train)
        predictions = model.predict(x_val)
        full_preds[y_val.index] = predictions

        print(f'\nfold: {fold + 1}, accuracy: {accuracy_score(predictions, y_val)}')
        print(f'fold: {fold + 1}, f1-score-macro: {f1_score(y_val, predictions, average="macro")}')
        print(f'fold: {fold + 1}, f1-score-weighted: {f1_score(y_val, predictions, average="weighted")}')
        if fold == 4:
            plot_importance(model)
        
    return full_preds

# %%
preds = xgb_run(new_df)
# Out:
# fold: 1, accuracy: 0.729151817533856
# fold: 1, f1-score-macro: 0.676602706488473
# fold: 1, f1-score-weighted: 0.7234101471759421
#
# fold: 2, accuracy: 0.7348538845331433
# fold: 2, f1-score-macro: 0.682222809796823
# fold: 2, f1-score-weighted: 0.7292187832624805
#
# fold: 3, accuracy: 0.7263007840342124
# fold: 3, f1-score-macro: 0.6738540676703128
# fold: 3, f1-score-weighted: 0.7225553620868663
#
# fold: 4, accuracy: 0.7441197434069851
# fold: 4, f1-score-macro: 0.6708930789680724
# fold: 4, f1-score-weighted: 0.7365863027836919
#
# fold: 5, accuracy: 0.744832501781896
# fold: 5, f1-score-macro: 0.690297914305067
# fold: 5, f1-score-weighted: 0.74105577000352

# %%
conf_matrix = confusion_matrix(new_df['class'], preds)
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(conf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(new_df['class'], preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.35      0.41       617
#            1       0.70      0.85      0.77      3222
#            2       0.81      0.69      0.75      2565
#            3       0.94      0.68      0.79       611
#
#     accuracy                           0.74      7015
#    macro avg       0.74      0.64      0.68      7015
# weighted avg       0.74      0.74      0.73      7015

# %%
train_df, test_df = train_test_split(new_df, test_size=0.2, 
                                     random_state=0, stratify=new_df['class'])
train_df.index = range(len(train_df))
test_df.index = range(len(test_df))

# %%
# I used copypaste with little changes from here https://github.com/optuna/optuna-examples/blob/main/xgboost/xgboost_simple.py
import optuna
import xgboost as xgb
import numpy as np

def objective(trial, data, metric_func):
    pred_vals = np.zeros(len(data))
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        train_x, train_y = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        valid_x, valid_y = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
        dtrain = xgb.DMatrix(train_x, label=train_y)
        dvalid = xgb.DMatrix(valid_x, label=valid_y)

        param = {
            "verbosity": 0,
            #"objective": "multi:softprob",
            "objective": "binary:logistic",
            #"eval_metric": "merror",
            #"num_class": len(data['class'].unique()),
            # use exact for small dataset.
            "tree_method": "exact",
            # defines booster, gblinear for linear functions.
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            # L2 regularization weight.
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            # L1 regularization weight.
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
            # sampling ratio for training data.
            "subsample": trial.suggest_float("subsample", 0.2, 1.0),
            # sampling according to each tree.
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
        }

        if param["booster"] in ["gbtree", "dart"]:
            # maximum depth of the tree, signifies complexity of the tree.
            param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
            # minimum child weight, larger the term more conservative the tree.
            param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
            param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            # defines how selective algorithm is.
            param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

        if param["booster"] == "dart":
            param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
            param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
            param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
            param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

        bst = xgb.train(param, dtrain)
        preds = bst.predict(dvalid)
        pred_labels = np.rint(preds)
        pred_vals[valid_y.index] = pred_labels
    
    return metric_func(data["class"], pred_vals)

def optuna_with_metric(data, metric_func, models=None):
    accuracy_vals = np.zeros(len(data))

    pred_vals = np.zeros(len(data))
    if models is None:
        objective_with_df = lambda trials: objective(trials, data, metric_func)
        study = optuna.create_study(direction="maximize")
        study.optimize(objective_with_df, n_trials=200)

        params = study.best_trial.params
        params['objective'] = 'binary:logistic'
        models = []
        kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
        for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
            train_x, train_y = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
            valid_x, valid_y = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
            dtrain = xgb.DMatrix(train_x, label=train_y)
            dvalid = xgb.DMatrix(valid_x, label=valid_y)

            models.append(xgb.train(params, dtrain))
            preds = models[fold].predict(dvalid)
            pred_labels = np.rint(preds)
            pred_vals[valid_y.index] = pred_labels
        
        return pred_vals, models
    else:
        dmatrix = xgb.DMatrix(data.drop('class', axis=1))
        for model in models:
            pred_vals += model.predict(dmatrix)
        pred_vals /= len(models)
        pred_vals = np.rint(pred_vals)
        
        return pred_vals, models

# %%
# I can't improove model. No one attempt of improvements didn't get better results.

# %%
def objective2(trial, data, metric_func, avrg):
    pred_vals = np.zeros(len(data))
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        train_x, train_y = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        valid_x, valid_y = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
        dtrain = xgb.DMatrix(train_x, label=train_y)
        dvalid = xgb.DMatrix(valid_x, label=valid_y)

        param = {
            "verbosity": 0,
            "objective": "multi:softprob",
            #"objective": "binary:logistic",
            #"eval_metric": "merror",
            "num_class": len(data['class'].unique()),
            # use exact for small dataset.
            #"tree_method": "exact",
            # defines booster, gblinear for linear functions.
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            # L2 regularization weight.
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            # L1 regularization weight.
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
            # sampling ratio for training data.
            "subsample": trial.suggest_float("subsample", 0.2, 1.0),
            # sampling according to each tree.
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
        }

        if param["booster"] in ["gbtree", "dart"]:
            # maximum depth of the tree, signifies complexity of the tree.
            param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
            # minimum child weight, larger the term more conservative the tree.
            param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
            param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            # defines how selective algorithm is.
            param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

        if param["booster"] == "dart":
            param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
            param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
            param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
            param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

        bst = xgb.train(param, dtrain)
        preds = bst.predict(dvalid)
        pred_labels = np.rint(preds)
        pred_vals[valid_y.index] = np.argmax(pred_labels, axis=1)
        
    if avrg:
        return metric_func(data["class"], pred_vals, average=avrg)
    else:
        return metric_func(data["class"], pred_vals)
    

def optuna_multiclass(data, metric_func, avrg, models=None):
    accuracy_vals = np.zeros(len(data))

    pred_vals = np.zeros((len(data), 4))
    if models is None:
        objective_with_df = lambda trials: objective2(trials, data, metric_func, avrg)
        study = optuna.create_study(direction="maximize")
        study.optimize(objective_with_df, n_trials=200)

        params = study.best_trial.params
        params['objective'] = "multi:softprob"
        #params['eval_metric'] = 'merror'
        params['num_class'] = 4
        models = []
        kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
        for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
            train_x, train_y = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
            valid_x, valid_y = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
            dtrain = xgb.DMatrix(train_x, label=train_y)
            dvalid = xgb.DMatrix(valid_x, label=valid_y)

            models.append(xgb.train(params, dtrain))
            preds = models[fold].predict(dvalid)
            pred_vals[valid_y.index] = preds
        return pred_vals, models
    else:
        dmatrix = xgb.DMatrix(data.drop('class', axis=1))
        for model in models:
            pred_vals += model.predict(dmatrix)
        pred_vals /= len(models)
        pred_vals = np.rint(pred_vals)
        
        return pred_vals, models

# %%
def xgb_prob_run(data, models=None):
    full_preds = np.zeros((len(data), 4))
    if models is None:
        models = []
        kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
        for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
            x_train, y_train = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
            x_val, y_val = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']

            models.append(XGBClassifier(silent=True, verbosity=0))
            models[fold].fit(x_train, y_train)
            predictions = models[fold].predict_proba(x_val)
            full_preds[y_val.index] = predictions
        
        return full_preds, models
    else:
        for model in models:
            full_preds += model.predict_proba(data.drop('class', axis=1))
        full_preds /= len(models)
        full_preds = np.rint(full_preds)
        
        return full_preds, models

# %%
def objective3(trial, data, abcd_targets, 
               all_vs_all_f1_preds, all_vs_all_accuracy_preds,
               all_vs_all_precision_preds, all_vs_all_recall_preds,
               all_vs_all_standard_preds):
    abcd_trial = trial.suggest_float("abcd_targets", 0.0, 1.0)
    f1_trial = trial.suggest_float("all_f1", 0.0, 1.0)
    accuracy_trial = trial.suggest_float("all_accuracy", 0.0, 1.0)
    precision_trial = trial.suggest_float("all_precision", 0.0, 1.0)
    recall_trial = trial.suggest_float("all_recall", 0.0, 1.0)
    standard_trial = trial.suggest_float("all_standard", 0.0, 1.0)
    
    all_weights = abcd_trial + f1_trial + accuracy_trial \
                  + precision_trial + recall_trial + standard_trial
    if all_weights < 1e-4:
        all_weights = 1e-4
    
    abcd_weight = abcd_trial / all_weights
    f1_weight = f1_trial / all_weights
    accuracy_weight = accuracy_trial / all_weights
    precision_weight = precision_trial / all_weights
    recall_weight = recall_trial / all_weights
    standard_weight = standard_trial / all_weights
    
    targets = (abcd_targets * abcd_weight) + (all_vs_all_f1_preds * f1_weight) \
              + (all_vs_all_accuracy_preds * accuracy_weight) \
              + (all_vs_all_precision_preds * precision_weight) \
              + (all_vs_all_recall_preds * recall_weight) \
              + (all_vs_all_standard_preds * standard_weight)
    target_preds = np.argmax(targets, axis=1)
    
    return accuracy_score(data["class"], target_preds)

def optuna_weights(data, abcd_targets, 
                   all_vs_all_f1_preds, all_vs_all_accuracy_preds,
                   all_vs_all_precision_preds, all_vs_all_recall_preds,
                   all_vs_all_standard_preds):
    objective_with_df = lambda trials: objective3(trials, data, abcd_targets,
                                                  all_vs_all_f1_preds, 
                                                  all_vs_all_accuracy_preds,
                                                  all_vs_all_precision_preds, 
                                                  all_vs_all_recall_preds,
                                                  all_vs_all_standard_preds)
    study = optuna.create_study(direction="maximize")
    study.optimize(objective_with_df, n_trials=1000)
    
    p = study.best_trial.params
    all_weights = p['abcd_targets'] + p['all_f1'] + p['all_accuracy'] \
                      + p['all_precision'] + p['all_recall'] + p['all_standard']
    if all_weights < 1e-4:
        all_weights = 1e-4

    abcd_weight = p['abcd_targets'] / all_weights
    f1_weight = p['all_f1'] / all_weights
    accuracy_weight = p['all_accuracy'] / all_weights
    precision_weight = p['all_precision'] / all_weights
    recall_weight = p['all_recall'] / all_weights
    standard_weight = p['all_standard'] / all_weights

    targets = (abcd_targets * abcd_weight) + (all_vs_all_f1_preds * f1_weight) \
              + (all_vs_all_accuracy_preds * accuracy_weight) \
              + (all_vs_all_precision_preds * precision_weight) \
              + (all_vs_all_recall_preds * recall_weight) \
              + (all_vs_all_standard_preds * standard_weight)
    target_preds = np.argmax(targets, axis=1)
    
    return target_preds, p

# %%
def pipeline(data, all_models=None):
    a_vs_all_df = data.copy()
    a_vs_all_df['class'] = a_vs_all_df['class'].replace({0: 1, 1: 0, 2: 0, 3: 0})
    
    b_vs_all_df = data.copy()
    b_vs_all_df['class'] = b_vs_all_df['class'].replace({0: 0, 1: 1, 2: 0, 3: 0})
    
    c_vs_all_df = data.copy()
    c_vs_all_df['class'] = c_vs_all_df['class'].replace({0: 0, 1: 0, 2: 1, 3: 0})
    
    d_vs_all_df = data.copy()
    d_vs_all_df['class'] = d_vs_all_df['class'].replace({0: 0, 1: 0, 2: 0, 3: 1})
    
    checker = True
    if all_models is None:
        checker = False
        all_models = dict()
    
    if not checker:
        a_vs_all_models = None
        b_vs_all_models = None
        c_vs_all_models = None
        d_vs_all_models = None
    else:
        a_vs_all_models = all_models['a_vs_all_models']
        b_vs_all_models = all_models['b_vs_all_models']
        c_vs_all_models = all_models['c_vs_all_models']
        d_vs_all_models = all_models['d_vs_all_models']
    
    a_vs_all_preds, all_models['a_vs_all_models'] = optuna_with_metric(a_vs_all_df, 
                                                                       recall_score, 
                                                                       a_vs_all_models)
    b_vs_all_preds, all_models['b_vs_all_models'] = optuna_with_metric(b_vs_all_df, 
                                                                       f1_score, 
                                                                       b_vs_all_models)
    c_vs_all_preds, all_models['c_vs_all_models'] = optuna_with_metric(c_vs_all_df, 
                                                                       f1_score, 
                                                                       c_vs_all_models)
    d_vs_all_preds, all_models['d_vs_all_models'] = optuna_with_metric(d_vs_all_df, 
                                                                       f1_score, 
                                                                       d_vs_all_models)
    
    a_vs_all_preds
    a_vs_all_preds = np.where(a_vs_all_preds == 0.0, -1, a_vs_all_preds)
    
    b_vs_all_preds
    b_vs_all_preds = np.where(b_vs_all_preds == 0.0, -1, b_vs_all_preds)
    
    c_vs_all_preds
    c_vs_all_preds = np.where(c_vs_all_preds == 0.0, -1, c_vs_all_preds)
    
    d_vs_all_preds
    d_vs_all_preds = np.where(d_vs_all_preds == 0.0, -1, d_vs_all_preds)
    
    if not checker:
        all_vs_all_f1_models = None
        all_vs_all_accuracy_models = None
        all_vs_all_precision_models = None
        all_vs_all_recall_models = None
    else:
        all_vs_all_f1_models = all_models['all_vs_all_f1_models']
        all_vs_all_accuracy_models = all_models['all_vs_all_accuracy_models']
        all_vs_all_precision_models = all_models['all_vs_all_precision_models']
        all_vs_all_recall_models = all_models['all_vs_all_recall_models']
    
    all_vs_all_f1_preds, all_models['all_vs_all_f1_models'] = \
                                            optuna_multiclass(data, f1_score, "weighted",
                                                              all_vs_all_f1_models)
    all_vs_all_accuracy_preds, all_models['all_vs_all_accuracy_models'] = \
                                            optuna_multiclass(data, accuracy_score, None,
                                                              all_vs_all_accuracy_models)
    all_vs_all_recall_preds, all_models['all_vs_all_recall_models'] = \
                                            optuna_multiclass(data, recall_score, "weighted",
                                                              all_vs_all_recall_models)
    all_vs_all_precision_preds, all_models['all_vs_all_precision_models'] = \
                                            optuna_multiclass(data, precision_score, "weighted",
                                                              all_vs_all_precision_models)
    
    if not checker:
        all_vs_all_standard_models = None
    else:
        all_vs_all_standard_models = all_models['all_vs_all_standard_models']
    all_vs_all_standard_preds, all_models['all_vs_all_standard_models'] = \
                                            xgb_prob_run(data, all_vs_all_standard_models)
    
    a = np.expand_dims(a_vs_all_preds, axis=0)
    b = np.expand_dims(b_vs_all_preds, axis=0)
    c = np.expand_dims(c_vs_all_preds, axis=0)
    d = np.expand_dims(d_vs_all_preds, axis=0)
    abcd_targets = np.concatenate([a, b, c, d], axis=0).T
    
    p = None
    if not checker:
        target_preds, all_models['weights'] = optuna_weights(data, abcd_targets, 
                                                             all_vs_all_f1_preds, 
                                                             all_vs_all_accuracy_preds,
                                                             all_vs_all_precision_preds, 
                                                             all_vs_all_recall_preds,
                                                             all_vs_all_standard_preds)
    else:
        p = all_models['weights']
        all_weights = p['abcd_targets'] + p['all_f1'] + p['all_accuracy'] \
                    + p['all_precision'] + p['all_recall'] + p['all_standard']
        if all_weights < 1e-4:
            all_weights = 1e-4

        abcd_weight = p['abcd_targets'] / all_weights
        f1_weight = p['all_f1'] / all_weights
        accuracy_weight = p['all_accuracy'] / all_weights
        precision_weight = p['all_precision'] / all_weights
        recall_weight = p['all_recall'] / all_weights
        standard_weight = p['all_standard'] / all_weights

        a = np.expand_dims(a_vs_all_preds, axis=0)
        b = np.expand_dims(b_vs_all_preds, axis=0)
        c = np.expand_dims(c_vs_all_preds, axis=0)
        d = np.expand_dims(d_vs_all_preds, axis=0)
        abcd_targets = np.concatenate([a, b, c, d], axis=0).T
        targets = (abcd_targets * abcd_weight) + (all_vs_all_f1_preds * f1_weight) \
                  + (all_vs_all_accuracy_preds * accuracy_weight) \
                  + (all_vs_all_precision_preds * precision_weight) \
                  + (all_vs_all_recall_preds * recall_weight) \
                  + (all_vs_all_standard_preds * standard_weight)
        target_preds = np.argmax(targets, axis=1)

    return target_preds, all_models

# %%
train_preds, all_models = pipeline(train_df)
# Out:
# [I 2022-01-17 18:44:05,562] A new study created in memory with name: no-name-2d848ad3-5724-4372-b405-6991dd9dccf7
# [I 2022-01-17 18:44:05,714] Trial 0 finished with value: 0.20850202429149797 and parameters: {'booster': 'dart', 'lambda': 1.1486489073071652e-06, 'alpha': 3.2537250226297616e-06, 'subsample': 0.30564496402345204, 'colsample_bytree': 0.844960781348983, 'max_depth': 3, 'min_child_weight': 5, 'eta': 0.6753047877457791, 'gamma': 3.4451057630819556e-05, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 4.916107426151736e-06, 'skip_drop': 1.2350947393400798e-08}. Best is trial 0 with value: 0.20850202429149797.
# ...

# %%
conf_matrix = confusion_matrix(train_df['class'], train_preds)
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(conf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
f1_score(train_df["class"], train_preds, average='weighted')
# Out:
# 0.733842089247903

# %%
accuracy_score(train_df["class"], train_preds)
# Out:
# 0.7437633642195296

# %%
test_preds, all_models = pipeline(test_df, all_models)

# %%
conf_matrix = confusion_matrix(test_df['class'], test_preds)
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(conf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
f1_score(test_df["class"], test_preds, average='weighted')
# Out:
# 0.7406641396612111

# %%
accuracy_score(test_df["class"], test_preds)
# Out:
# 0.7483962936564504

# %%
# Overfitting didn't confirm
