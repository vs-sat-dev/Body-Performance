# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bodyPerformanceI.csv')
df
# Out:
#        age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     24.0      F      152.4       42.5        23.4       57.0     112.0
# 1     27.0      F      162.1       70.9        35.7       97.0     148.0
# 2     23.0      M      173.7       68.3        13.6       76.0     137.0
# 3     31.0      M      168.2       70.5        15.5       82.0     145.0
# 4     25.0      M      175.1       64.8         6.9       65.0     118.0
# ...    ...    ...        ...        ...         ...        ...       ...
# 7010  21.0      M      179.6       78.6        16.3       64.0     118.0
# 7011  56.0      M      166.8       64.0        21.4       75.0     132.0
# 7012  26.0      M      177.4       78.3        14.0       74.0     115.0
# 7013  49.0      M      177.2       83.0        19.7       98.0     158.0
# 7014  43.0      F      161.5       49.9        29.8       79.0     155.0
#
#       gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0          27.4                     14.2            50.0          184.0     C
# 1          30.6                     11.0            42.0          157.0     D
# 2          47.7                     16.5            48.0          208.0     C
# 3          39.6                     19.9            66.0          264.0     C
# 4          42.0                     19.8            49.0          252.0     B
# ...         ...                      ...             ...            ...   ...
# 7010       54.1                     25.9            58.0          248.0     B
# 7011       50.7                     13.0            36.0          197.0     B
# 7012       53.3                     15.3            63.0          234.0     A
# 7013       40.2                     14.9            50.0          203.0     C
# 7014       21.0                     16.5            23.0          146.0     C
#
# [7015 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7015 entries, 0 to 7014
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      7015 non-null   float64
#  1   gender                   7015 non-null   object
#  2   height_cm                7015 non-null   float64
#  3   weight_kg                7015 non-null   float64
#  4   body fat_%               7015 non-null   float64
#  5   diastolic                7015 non-null   float64
#  6   systolic                 7015 non-null   float64
#  7   gripForce                7015 non-null   float64
#  8   sit and bend forward_cm  7015 non-null   float64
#  9   sit-ups counts           7015 non-null   float64
#  10  broad jump_cm            7015 non-null   float64
#  11  class                    7015 non-null   object
# dtypes: float64(10), object(2)
# memory usage: 657.8+ KB

# %%
df.isnull().sum()
# Out:
# age                        0
# gender                     0
# height_cm                  0
# weight_kg                  0
# body fat_%                 0
# diastolic                  0
# systolic                   0
# gripForce                  0
# sit and bend forward_cm    0
# sit-ups counts             0
# broad jump_cm              0
# class                      0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# M    4552
# F    2463
# Name: gender, dtype: int64

# %%
df['class'].value_counts()
# Out:
# B    3222
# C    2565
# A     617
# D     611
# Name: class, dtype: int64

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        fig, ax = plt.subplots(figsize=(12, 6))
        ax = sns.histplot(data=df[column])
        ax.set_title(column)
    elif df[column].dtype == 'float64':
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))
        sns.boxplot(data=df[column], ax=ax[0])
        ax[0].set_title(column)
        
        sns.distplot(x=df[column], ax=ax[1]);
        ax[1].set_title(column)

# %%
new_df = df.copy()
new_df['gender'] = df['gender'].replace({'M': 0, 'F': 1})
new_df['class'] =  df['class'].replace({'A': 0, 'B': 1, 'C': 2, 'D': 3})
new_df
# Out:
#        age  gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0     24.0       1      152.4       42.5        23.4       57.0     112.0
# 1     27.0       1      162.1       70.9        35.7       97.0     148.0
# 2     23.0       0      173.7       68.3        13.6       76.0     137.0
# 3     31.0       0      168.2       70.5        15.5       82.0     145.0
# 4     25.0       0      175.1       64.8         6.9       65.0     118.0
# ...    ...     ...        ...        ...         ...        ...       ...
# 7010  21.0       0      179.6       78.6        16.3       64.0     118.0
# 7011  56.0       0      166.8       64.0        21.4       75.0     132.0
# 7012  26.0       0      177.4       78.3        14.0       74.0     115.0
# 7013  49.0       0      177.2       83.0        19.7       98.0     158.0
# 7014  43.0       1      161.5       49.9        29.8       79.0     155.0
#
#       gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm  class
# 0          27.4                     14.2            50.0          184.0      2
# 1          30.6                     11.0            42.0          157.0      3
# 2          47.7                     16.5            48.0          208.0      2
# 3          39.6                     19.9            66.0          264.0      2
# 4          42.0                     19.8            49.0          252.0      1
# ...         ...                      ...             ...            ...    ...
# 7010       54.1                     25.9            58.0          248.0      1
# 7011       50.7                     13.0            36.0          197.0      1
# 7012       53.3                     15.3            63.0          234.0      0
# 7013       40.2                     14.9            50.0          203.0      2
# 7014       21.0                     16.5            23.0          146.0      2
#
# [7015 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(new_df.corr(), ax=ax, annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = new_df.corr()
unstacked = corr.unstack()
for e, u in enumerate(unstacked):
    if u == 1:
        unstacked[e] = 0

# %%
#Max absolute correlation
unstacked.abs().sort_values(ascending=False)
# Out:
# gender      gripForce     0.811698
# gripForce   gender        0.811698
# weight_kg   height_cm     0.761105
# height_cm   weight_kg     0.761105
# weight_kg   gripForce     0.752092
#                             ...
# body fat_%  body fat_%    0.000000
# weight_kg   weight_kg     0.000000
# height_cm   height_cm     0.000000
# gender      gender        0.000000
# class       class         0.000000
# Length: 144, dtype: float64

# %%
#Max positive correlation
unstacked.sort_values(ascending=False)
# Out:
# weight_kg       height_cm        0.761105
# height_cm       weight_kg        0.761105
# weight_kg       gripForce        0.752092
# gripForce       weight_kg        0.752092
# sit-ups counts  broad jump_cm    0.740434
#                                    ...
# height_cm       gender          -0.723391
# broad jump_cm   gender          -0.727814
# gender          broad jump_cm   -0.727814
#                 gripForce       -0.811698
# gripForce       gender          -0.811698
# Length: 144, dtype: float64

# %%
#Max negative correlation
unstacked.sort_values(ascending=True)
# Out:
# gripForce      gender           -0.811698
# gender         gripForce        -0.811698
#                broad jump_cm    -0.727814
# broad jump_cm  gender           -0.727814
# height_cm      gender           -0.723391
#                                    ...
# broad jump_cm  sit-ups counts    0.740434
# weight_kg      gripForce         0.752092
# gripForce      weight_kg         0.752092
# weight_kg      height_cm         0.761105
# height_cm      weight_kg         0.761105
# Length: 144, dtype: float64

# %%
# Max absolute correlation for target feature class
corr.loc[corr.index == 'class'].abs().max().sort_values(ascending=False)[1:]
# Out:
# sit and bend forward_cm    0.459989
# sit-ups counts             0.317935
# body fat_%                 0.216034
# broad jump_cm              0.180268
# weight_kg                  0.122481
# gripForce                  0.100442
# gender                     0.049443
# diastolic                  0.037550
# height_cm                  0.031961
# age                        0.024815
# systolic                   0.019069
# dtype: float64

# %%
# Max positive correlation for target feature class
corr.loc[corr.index == 'class'].max().sort_values(ascending=False)[1:]
# Out:
# body fat_%                 0.216034
# weight_kg                  0.122481
# diastolic                  0.037550
# height_cm                  0.031961
# age                        0.024815
# systolic                   0.019069
# gender                    -0.049443
# gripForce                 -0.100442
# broad jump_cm             -0.180268
# sit-ups counts            -0.317935
# sit and bend forward_cm   -0.459989
# dtype: float64

# %%
# Max negative correlation for target feature class
corr.loc[corr.index == 'class'].min().sort_values(ascending=True)
# Out:
# sit and bend forward_cm   -0.459989
# sit-ups counts            -0.317935
# broad jump_cm             -0.180268
# gripForce                 -0.100442
# gender                    -0.049443
# systolic                   0.019069
# age                        0.024815
# height_cm                  0.031961
# diastolic                  0.037550
# weight_kg                  0.122481
# body fat_%                 0.216034
# class                      1.000000
# dtype: float64

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
def xgb_run(data):
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        x_train, y_train = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        x_val, y_val = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']

        model = XGBClassifier(silent=True, verbosity=0)
        model.fit(x_train, y_train)
        predictions = model.predict(x_val)

        print(f'fold: {fold + 1}, accuracy: {accuracy_score(predictions, y_val)}')

# %%
xgb_run(new_df)
# Out:
# fold: 1, accuracy: 0.729151817533856
# fold: 2, accuracy: 0.7348538845331433
# fold: 3, accuracy: 0.7263007840342124
# fold: 4, accuracy: 0.7441197434069851
# fold: 5, accuracy: 0.744832501781896

# %%
from imblearn.over_sampling import SMOTE

def xgb_oversample_run(data):
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        x_train, y_train = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        x_val, y_val = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
        
        oversample = SMOTE()
        oversampled_x, oversampled_y = oversample.fit_resample(x_train, y_train)

        model = XGBClassifier(silent=True, verbosity=0)
        model.fit(oversampled_x, oversampled_y)
        predictions = model.predict(x_val)

        print(f'fold: {fold + 1}, accuracy: {accuracy_score(predictions, y_val)}')

# %%
xgb_oversample_run(new_df)
# Out:
# fold: 1, accuracy: 0.7077690662865289
# fold: 2, accuracy: 0.7277263007840342
# fold: 3, accuracy: 0.7263007840342124
# fold: 4, accuracy: 0.7327156094084105
# fold: 5, accuracy: 0.7419814682822523

# %%
# I used copypaste with little changes from here https://github.com/optuna/optuna-examples/blob/main/xgboost/xgboost_simple.py
import optuna
import xgboost as xgb
import numpy as np

def objective(trial, data):
    accuracy_vals = np.zeros(len(data))
    kfold = StratifiedKFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('class', axis=1), data['class'])):
        train_x, train_y = data.loc[trn_ind].drop('class', axis=1), data.loc[trn_ind, 'class']
        valid_x, valid_y = data.loc[val_ind].drop('class', axis=1), data.loc[val_ind, 'class']
        dtrain = xgb.DMatrix(train_x, label=train_y)
        dvalid = xgb.DMatrix(valid_x, label=valid_y)

        param = {
            "verbosity": 0,
            "objective": "multi:softprob",
            #"eval_metric": "mlogloss",
            "num_class": len(data['class'].unique()),
            # use exact for small dataset.
            "tree_method": "exact",
            # defines booster, gblinear for linear functions.
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            # L2 regularization weight.
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            # L1 regularization weight.
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
            # sampling ratio for training data.
            "subsample": trial.suggest_float("subsample", 0.2, 1.0),
            # sampling according to each tree.
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.2, 1.0),
        }

        if param["booster"] in ["gbtree", "dart"]:
            # maximum depth of the tree, signifies complexity of the tree.
            param["max_depth"] = trial.suggest_int("max_depth", 3, 9, step=2)
            # minimum child weight, larger the term more conservative the tree.
            param["min_child_weight"] = trial.suggest_int("min_child_weight", 2, 10)
            param["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            # defines how selective algorithm is.
            param["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            param["grow_policy"] = trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])

        if param["booster"] == "dart":
            param["sample_type"] = trial.suggest_categorical("sample_type", ["uniform", "weighted"])
            param["normalize_type"] = trial.suggest_categorical("normalize_type", ["tree", "forest"])
            param["rate_drop"] = trial.suggest_float("rate_drop", 1e-8, 1.0, log=True)
            param["skip_drop"] = trial.suggest_float("skip_drop", 1e-8, 1.0, log=True)

        bst = xgb.train(param, dtrain)
        preds = bst.predict(dvalid)
        pred_labels = np.argmax(preds, axis=1)
        accuracy_temp = accuracy_score(valid_y, pred_labels)
        #print(f'fold: {fold + 1}, accuracy: {accuracy_temp}')
        accuracy_vals[valid_y.index] = pred_labels
    
    return accuracy_score(accuracy_vals, data['class'].values)

objective_with_df = lambda trials: objective(trials, new_df)
study = optuna.create_study(direction="maximize")
study.optimize(objective_with_df, n_trials=200)
# Out:
# [I 2022-01-12 05:27:50,730] A new study created in memory with name: no-name-9786cbbd-3431-4e5f-ae23-242109f18c40
# [I 2022-01-12 05:27:51,143] Trial 0 finished with value: 0.5442622950819672 and parameters: {'booster': 'dart', 'lambda': 0.12654041776687824, 'alpha': 1.220759231165897e-08, 'subsample': 0.7331223349690721, 'colsample_bytree': 0.21578508882893424, 'max_depth': 5, 'min_child_weight': 2, 'eta': 1.6253332883051225e-07, 'gamma': 0.0012365427488409734, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 1.8696153980489325e-06, 'skip_drop': 8.814246361945978e-05}. Best is trial 0 with value: 0.5442622950819672.
# [I 2022-01-12 05:27:51,389] Trial 1 finished with value: 0.6521739130434783 and parameters: {'booster': 'gbtree', 'lambda': 0.010124493041057135, 'alpha': 0.004806379966342365, 'subsample': 0.4961278111842461, 'colsample_bytree': 0.5042755692892411, 'max_depth': 3, 'min_child_weight': 9, 'eta': 0.40719181651189407, 'gamma': 5.211355465706218e-05, 'grow_policy': 'depthwise'}. Best is trial 1 with value: 0.6521739130434783.
# [I 2022-01-12 05:27:51,881] Trial 2 finished with value: 0.6711332858161083 and parameters: {'booster': 'dart', 'lambda': 0.0019671862991192915, 'alpha': 1.3429761337020466e-05, 'subsample': 0.316943253276698, 'colsample_bytree': 0.9741444949990485, 'max_depth': 5, 'min_child_weight': 10, 'eta': 0.9169273667514346, 'gamma': 8.059033740462501e-06, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 3.793012067411003e-05, 'skip_drop': 0.00041870306218414816}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:52,227] Trial 3 finished with value: 0.6106913756236636 and parameters: {'booster': 'dart', 'lambda': 0.7229570262937128, 'alpha': 0.005208400420096742, 'subsample': 0.7102390185740473, 'colsample_bytree': 0.6757083089524867, 'max_depth': 3, 'min_child_weight': 9, 'eta': 0.00035622042312747455, 'gamma': 0.08800187284228059, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 1.2577431011061656e-06, 'skip_drop': 0.17078760285601657}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:52,575] Trial 4 finished with value: 0.6145402708481824 and parameters: {'booster': 'dart', 'lambda': 0.00962068186369299, 'alpha': 8.45984520393225e-08, 'subsample': 0.5785775132793243, 'colsample_bytree': 0.6662937265196895, 'max_depth': 3, 'min_child_weight': 2, 'eta': 0.009360245587588426, 'gamma': 0.00946935752039242, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 7.1564446647008385e-06, 'skip_drop': 1.4702667837485838e-07}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:52,834] Trial 5 finished with value: 0.6095509622238061 and parameters: {'booster': 'gbtree', 'lambda': 1.4260897677669429e-05, 'alpha': 0.004554232581422688, 'subsample': 0.42508933295936635, 'colsample_bytree': 0.7098464728449667, 'max_depth': 3, 'min_child_weight': 3, 'eta': 4.015974194645575e-06, 'gamma': 0.00683891613582535, 'grow_policy': 'lossguide'}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:53,167] Trial 6 finished with value: 0.6162508909479686 and parameters: {'booster': 'dart', 'lambda': 0.032818651044964835, 'alpha': 0.027536087219130503, 'subsample': 0.8650943868861181, 'colsample_bytree': 0.6540078566047348, 'max_depth': 3, 'min_child_weight': 8, 'eta': 6.268357043552555e-06, 'gamma': 4.3389136588909393e-08, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'forest', 'rate_drop': 0.00032200577268087435, 'skip_drop': 6.842433328325675e-05}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:53,739] Trial 7 finished with value: 0.6419101924447612 and parameters: {'booster': 'dart', 'lambda': 0.022598462338770272, 'alpha': 8.602273124468236e-06, 'subsample': 0.8789199346194716, 'colsample_bytree': 0.33172395183346026, 'max_depth': 7, 'min_child_weight': 10, 'eta': 0.1699740500921951, 'gamma': 2.9106073046698693e-05, 'grow_policy': 'lossguide', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 4.602475643058327e-06, 'skip_drop': 0.002321455599478123}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:54,002] Trial 8 finished with value: 0.6011404133998575 and parameters: {'booster': 'gbtree', 'lambda': 1.415993789677768e-06, 'alpha': 5.534785197137761e-07, 'subsample': 0.2730281766006461, 'colsample_bytree': 0.7254294785991613, 'max_depth': 3, 'min_child_weight': 7, 'eta': 2.1366176198869812e-06, 'gamma': 0.4403832399115901, 'grow_policy': 'lossguide'}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:54,483] Trial 9 finished with value: 0.6507483962936564 and parameters: {'booster': 'dart', 'lambda': 0.766708457345954, 'alpha': 0.0015208506448133564, 'subsample': 0.5550428943739598, 'colsample_bytree': 0.55171067478448, 'max_depth': 5, 'min_child_weight': 4, 'eta': 4.459126429439045e-06, 'gamma': 1.5258890599847155e-07, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0021835327068762188, 'skip_drop': 2.2740871720464945e-06}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:54,595] Trial 10 finished with value: 0.4593014967925873 and parameters: {'booster': 'gblinear', 'lambda': 3.449279223506029e-08, 'alpha': 0.7163767073269647, 'subsample': 0.2348710476840679, 'colsample_bytree': 0.9801327365906811}. Best is trial 2 with value: 0.6711332858161083.
# [I 2022-01-12 05:27:55,058] Trial 11 finished with value: 0.67712045616536 and parameters: {'booster': 'gbtree', 'lambda': 0.000816120398794825, 'alpha': 4.9775306173278635e-05, 'subsample': 0.39756076818712893, 'colsample_bytree': 0.994545009181605, 'max_depth': 5, 'min_child_weight': 10, 'eta': 0.9490446294721188, 'gamma': 7.766893067443919e-06, 'grow_policy': 'lossguide'}. Best is trial 11 with value: 0.67712045616536.
# [I 2022-01-12 05:27:55,176] Trial 12 finished with value: 0.5110477548111191 and parameters: {'booster': 'gblinear', 'lambda': 0.0004626897323557563, 'alpha': 3.921910555489549e-05, 'subsample': 0.3709074786637449, 'colsample_bytree': 0.9784287027699862}. Best is trial 11 with value: 0.67712045616536.
# [I 2022-01-12 05:27:55,894] Trial 13 finished with value: 0.6936564504632929 and parameters: {'booster': 'gbtree', 'lambda': 0.0003129857322368652, 'alpha': 3.0155795065494575e-06, 'subsample': 0.37196486195365713, 'colsample_bytree': 0.8510109992483514, 'max_depth': 9, 'min_child_weight': 6, 'eta': 0.012060936611681106, 'gamma': 2.3289758805524326e-06, 'grow_policy': 'lossguide'}. Best is trial 13 with value: 0.6936564504632929.
# [I 2022-01-12 05:27:56,675] Trial 14 finished with value: 0.6996436208125445 and parameters: {'booster': 'gbtree', 'lambda': 3.92442864710317e-05, 'alpha': 1.2905907380394246e-06, 'subsample': 0.4494865565813923, 'colsample_bytree': 0.841696134798066, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.004698684121609375, 'gamma': 7.55718046952131e-07, 'grow_policy': 'lossguide'}. Best is trial 14 with value: 0.6996436208125445.
# [I 2022-01-12 05:27:57,494] Trial 15 finished with value: 0.6965074839629366 and parameters: {'booster': 'gbtree', 'lambda': 1.069974767388099e-05, 'alpha': 1.3351626278489369e-06, 'subsample': 0.4769452128802095, 'colsample_bytree': 0.8527118149764523, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.0021111328135801294, 'gamma': 5.491474649949775e-07, 'grow_policy': 'lossguide'}. Best is trial 14 with value: 0.6996436208125445.
# [I 2022-01-12 05:27:58,329] Trial 16 finished with value: 0.7096222380612972 and parameters: {'booster': 'gbtree', 'lambda': 1.466668155894023e-05, 'alpha': 5.016878391165815e-07, 'subsample': 0.7071000153783805, 'colsample_bytree': 0.8257605917151006, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.0010071353562320377, 'gamma': 4.869128279721217e-07, 'grow_policy': 'lossguide'}. Best is trial 16 with value: 0.7096222380612972.
# [I 2022-01-12 05:27:58,970] Trial 17 finished with value: 0.6922309337134711 and parameters: {'booster': 'gbtree', 'lambda': 2.870994689146954e-07, 'alpha': 1.1477471036677683e-07, 'subsample': 0.6984863597158406, 'colsample_bytree': 0.8373095329240623, 'max_depth': 7, 'min_child_weight': 5, 'eta': 0.00033659239371780237, 'gamma': 1.3105501871365798e-08, 'grow_policy': 'lossguide'}. Best is trial 16 with value: 0.7096222380612972.
# [I 2022-01-12 05:27:59,799] Trial 18 finished with value: 0.7016393442622951 and parameters: {'booster': 'gbtree', 'lambda': 3.0152592607187025e-05, 'alpha': 0.00030415088420033214, 'subsample': 0.6516857080907853, 'colsample_bytree': 0.8023895814784773, 'max_depth': 9, 'min_child_weight': 6, 'eta': 9.550531850284248e-05, 'gamma': 5.630490267377335e-07, 'grow_policy': 'lossguide'}. Best is trial 16 with value: 0.7096222380612972.
# [I 2022-01-12 05:27:59,908] Trial 19 finished with value: 0.5103349964362082 and parameters: {'booster': 'gblinear', 'lambda': 1.8205260511258318e-06, 'alpha': 0.0004262108113605657, 'subsample': 0.6621886429360644, 'colsample_bytree': 0.465992058361708}. Best is trial 16 with value: 0.7096222380612972.
# [I 2022-01-12 05:28:00,587] Trial 20 finished with value: 0.6880969351389878 and parameters: {'booster': 'gbtree', 'lambda': 4.0829082977132e-08, 'alpha': 0.00017077559959826434, 'subsample': 0.9964997188199067, 'colsample_bytree': 0.7625709882733874, 'max_depth': 7, 'min_child_weight': 7, 'eta': 0.00010753178954958585, 'gamma': 7.847468165491496e-08, 'grow_policy': 'lossguide'}. Best is trial 16 with value: 0.7096222380612972.
# [I 2022-01-12 05:28:01,460] Trial 21 finished with value: 0.7131860299358518 and parameters: {'booster': 'gbtree', 'lambda': 6.462484286953397e-05, 'alpha': 1.2171650187650842e-07, 'subsample': 0.797803053931112, 'colsample_bytree': 0.7897185677951024, 'max_depth': 9, 'min_child_weight': 5, 'eta': 0.0028602349668774636, 'gamma': 6.859309047432786e-07, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.7131860299358518.
# [I 2022-01-12 05:28:02,247] Trial 22 finished with value: 0.7067712045616537 and parameters: {'booster': 'gbtree', 'lambda': 8.860078483695232e-05, 'alpha': 1.3341324421167144e-08, 'subsample': 0.7959808388752148, 'colsample_bytree': 0.8025093815163808, 'max_depth': 9, 'min_child_weight': 6, 'eta': 4.876254931597452e-05, 'gamma': 5.745027588741655e-07, 'grow_policy': 'lossguide'}. Best is trial 21 with value: 0.7131860299358518.
# [I 2022-01-12 05:28:03,160] Trial 23 finished with value: 0.7177476835352815 and parameters: {'booster': 'gbtree', 'lambda': 0.0001200323191842653, 'alpha': 1.4441885628840745e-08, 'subsample': 0.79904838635357, 'colsample_bytree': 0.8851178909383364, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.036539866111676526, 'gamma': 0.00026158258405723867, 'grow_policy': 'lossguide'}. Best is trial 23 with value: 0.7177476835352815.
# [I 2022-01-12 05:28:03,899] Trial 24 finished with value: 0.7033499643620813 and parameters: {'booster': 'gbtree', 'lambda': 2.8507698223437987e-06, 'alpha': 1.4052292924614862e-07, 'subsample': 0.8120649662933711, 'colsample_bytree': 0.9097837244023199, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.07072593732978316, 'gamma': 0.0004618051384584939, 'grow_policy': 'lossguide'}. Best is trial 23 with value: 0.7177476835352815.
# [I 2022-01-12 05:28:04,735] Trial 25 finished with value: 0.7181753385602281 and parameters: {'booster': 'gbtree', 'lambda': 0.002315317897351977, 'alpha': 2.3703882056837437e-08, 'subsample': 0.9592424853024197, 'colsample_bytree': 0.7618019263612028, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.040605838573412656, 'gamma': 0.0003052783638448741, 'grow_policy': 'lossguide'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:04,842] Trial 26 finished with value: 0.5087669280114041 and parameters: {'booster': 'gblinear', 'lambda': 0.00335251435877522, 'alpha': 2.3461841957893163e-08, 'subsample': 0.9810869411556103, 'colsample_bytree': 0.8896424364715381}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:05,635] Trial 27 finished with value: 0.697647897362794 and parameters: {'booster': 'gbtree', 'lambda': 0.00024971949140080614, 'alpha': 1.4329533978603165e-07, 'subsample': 0.9245974092379092, 'colsample_bytree': 0.5897232369065433, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.039198518395035235, 'gamma': 0.0002784839061703372, 'grow_policy': 'lossguide'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:06,421] Trial 28 finished with value: 0.7027797576621525 and parameters: {'booster': 'gbtree', 'lambda': 9.586794360051154e-05, 'alpha': 4.887911612407524e-08, 'subsample': 0.7883569609733163, 'colsample_bytree': 0.9248844655653152, 'max_depth': 7, 'min_child_weight': 4, 'eta': 0.02147934673551576, 'gamma': 0.0026163441172331265, 'grow_policy': 'lossguide'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:06,969] Trial 29 finished with value: 0.6034212401995723 and parameters: {'booster': 'gbtree', 'lambda': 0.003088622811527443, 'alpha': 1.2087764525494428e-08, 'subsample': 0.9297989888973395, 'colsample_bytree': 0.21848838766107653, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.10436694350734224, 'gamma': 0.00016960051327200875, 'grow_policy': 'lossguide'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:07,077] Trial 30 finished with value: 0.5062009978617249 and parameters: {'booster': 'gblinear', 'lambda': 2.2824156707489445e-07, 'alpha': 3.719847426207356e-07, 'subsample': 0.8474991097162606, 'colsample_bytree': 0.7585605992607196}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28
}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:15,091] Trial 40 finished with value: 0.6983606557377049 and parameters: {'booster': 'dart', 'lambda': 4.572350529225308e-05, 'alpha': 3.330589113476283e-06, 'subsample': 0.5100004943961167, 'colsample_bytree': 0.7237238355766479, 'max_depth': 7, 'min_child_weight': 3, 'eta': 0.1850289216222286, 'gamma': 0.04158758262011369, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.36776973254031237, 'skip_drop': 1.0164745979123762e-08}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:15,954] Trial 41 finished with value: 0.7121881682109765 and parameters: {'booster': 'gbtree', 'lambda': 3.057284008928392e-05, 'alpha': 1.7292168383617648e-07, 'subsample': 0.5436243749381506, 'colsample_bytree': 0.7613523665363898, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.2906203479521932, 'gamma': 0.037046527814653576, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:16,816] Trial 42 finished with value: 0.7100498930862438 and parameters: {'booster': 'gbtree', 'lambda': 0.00017545261070770187, 'alpha': 1.2853601428017375e-07, 'subsample': 0.5521054427585504, 'colsample_bytree': 0.8863620399685145, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.37384884420748676, 'gamma': 0.07353278100079566, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:17,649] Trial 43 finished with value: 0.7012116892373486 and parameters: {'booster': 'gbtree', 'lambda': 2.5697476257363914e-05, 'alpha': 2.3431590562798078e-08, 'subsample': 0.5178761278183466, 'colsample_bytree': 0.6940177437629931, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.05031090601536203, 'gamma': 0.019809373337794617, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:18,532] Trial 44 finished with value: 0.7063435495367071 and parameters: {'booster': 'gbtree', 'lambda': 0.001022012038446103, 'alpha': 2.0480966965092053e-05, 'subsample': 0.5998580717015962, 'colsample_bytree': 0.7375007642934625, 'max_depth': 9, 'min_child_weight': 2, 'eta': 0.493191819891494, 'gamma': 0.35903791308925925, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:19,389] Trial 45 finished with value: 0.7042052744119743 and parameters: {'booster': 'gbtree', 'lambda': 6.711635684028311e-05, 'alpha': 2.097146373503752e-07, 'subsample': 0.5498386130898887, 'colsample_bytree': 0.8024261620597349, 'max_depth': 9, 'min_child_weight': 3, 'eta': 0.011320025294020158, 'gamma': 0.19803485739783364, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:20,197] Trial 46 finished with value: 0.6815395580898076 and parameters: {'booster': 'dart', 'lambda': 0.0004046014004434784, 'alpha': 6.819499225495432e-08, 'subsample': 0.5969208111931904, 'colsample_bytree': 0.6423844852562839, 'max_depth': 9, 'min_child_weight': 4, 'eta': 0.33412814471003777, 'gamma': 0.014098961900969433, 'grow_policy': 'depthwise', 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.9618440997597554, 'skip_drop': 0.012608542683345408}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28:20,786] Trial 47 finished with value: 0.6859586600142552 and parameters: {'booster': 'gbtree', 'lambda': 0.052306213962600885, 'alpha': 0.6154101528302468, 'subsample': 0.7315752490205257, 'colsample_bytree': 0.5681094624363172, 'max_depth': 7, 'min_child_weight': 3, 'eta': 0.07642837646514988, 'gamma': 0.0031989271740531754, 'grow_policy': 'depthwise'}. Best is trial 25 with value: 0.7181753385602281.
# [I 2022-01-12 05:28
-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.04551171693308976, 'skip_drop': 6.47181967663086e-07}. Best is trial 74 with value: 0.726728439059159.
# [I 2022-01-12 05:28:47,894] Trial 79 finished with value: 0.7161796151104776 and parameters: {'booster': 'dart', 'lambda': 0.2352380803598524, 'alpha': 0.058392040222279507, 'subsample': 0.932348054321052, 'colsample_bytree': 0.9416846927932098, 'max_depth': 9, 'min_child_weight': 7, 'eta': 0.6924426092100842, 'gamma': 6.138549155596525e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.25741649883935847, 'skip_drop': 7.738184882137324e-07}. Best is trial 74 with value: 0.726728439059159.
# [I 2022-01-12 05:28:48,854] Trial 80 finished with value: 0.729151817533856 and parameters: {'booster': 'dart', 'lambda': 0.49525170314029865, 'alpha': 8.10240193675773e-05, 'subsample': 0.922517804149798, 'colsample_bytree': 0.9741306732758641, 'max_depth': 9, 'min_child_weight': 8, 'eta': 0.22454038200598428, 'gamma': 3.978341404231124e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.0060117300475495475, 'skip_drop': 3.962121133300007e-08}. Best is trial 80 with value: 0.729151817533856.
# [I 2022-01-12 05:28:49,836] Trial 81 finished with value: 0.7245901639344262 and parameters: {'booster': 'dart', 'lambda': 0.6322087915981467, 'alpha': 0.0013475312976751663, 'subsample': 0.975410798573532, 'colsample_bytree': 0.9997666105868266, 'max_depth': 9, 'min_child_weight': 8, 'eta': 0.24480239261430903, 'gamma': 3.7339876052573504e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.009214365844665054, 'skip_drop': 6.882150402812841e-08}. Best is trial 80 with value: 0.729151817533856.
# [I 2022-01-12 05:28:50,831] Trial 82 finished with value: 0.727583749109052 and parameters: {'booster': 'dart', 'lambda': 0.4526605395742681, 'alpha': 0.00016155506142691092, 'subsample': 0.9309969939928111, 'colsample_bytree': 0.9912474584245179, 'max_depth': 9, 'min_child_weight': 8, 'eta': 0.20283523580201995, 'gamma': 4.6040199140438554e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.006993403155501632, 'skip_drop': 4.5512096123952566e-08}. Best is trial 80 with value: 0.729151817533856.
# [I 2022-01-12 05:28:51,837] Trial 83 finished with value: 0.7297220242337847 and parameters: {'booster': 'dart', 'lambda': 0.42650001111826913, 'alpha': 0.0001988354136309641, 'subsample': 0.9297523564065836, 'colsample_bytree': 0.9979574823257767, 'max_depth': 9, 'min_child_weight': 7, 'eta': 0.2685657558673704, 'gamma': 4.3286392631798355e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.006591548322890836, 'skip_drop': 4.86307369813662e-07}. Best is trial 83 with value: 0.7297220242337847.
# [I 2022-01-12 05:28:52,844] Trial 84 finished with value: 0.726728439059159 and parameters: {'booster': 'dart', 'lambda': 0.43822712087462146, 'alpha': 0.00015382448751831486, 'subsample': 0.9362652327277016, 'colsample_bytree': 0.9974438228725019, 'max_depth': 9, 'min_child_weight': 8, 'eta': 0.23739631705829434, 'gamma': 4.22063063406084e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.004606940907602217, 'skip_drop': 5.229662036032367e-07}. Best is trial 83 with value: 0.7297220242337847.
# [I 2022-01-12 05:28:53,834] Trial 85 finished with value: 0.7321454027084818 and parameters: {'booster': 'dart', 'lambda': 0.39402397619357743, 'alpha': 0.00010362502000232174, 'subsample': 0.9227079456469466, 'colsample_bytree': 0.9959807200925573, 'max_depth': 9, 'min_child_weight': 8, 'eta': 0.25559369105603613, 'gamma': 3.930742702450902e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.
 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.4527539401076102, 'gamma': 1.7780129656271038e-07, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0007979837025200542, 'skip_drop': 0.1890331619603001}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:22,177] Trial 183 finished with value: 0.7257305773342837 and parameters: {'booster': 'dart', 'lambda': 0.06162411903756002, 'alpha': 5.387242693287801e-07, 'subsample': 0.9212515898319306, 'colsample_bytree': 0.9519142284383002, 'max_depth': 9, 'min_child_weight': 10, 'eta': 0.2078576342542258, 'gamma': 4.681048287043657e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0013181261138986784, 'skip_drop': 8.896011029782177e-07}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:23,164] Trial 184 finished with value: 0.7131860299358518 and parameters: {'booster': 'dart', 'lambda': 0.25466755051486684, 'alpha': 6.440886564052378e-08, 'subsample': 0.8901780221472488, 'colsample_bytree': 0.924928138001625, 'max_depth': 9, 'min_child_weight': 9, 'eta': 4.284580978456634e-05, 'gamma': 2.3699572720383145e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0003824765174024522, 'skip_drop': 0.36461547020876667}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:24,096] Trial 185 finished with value: 0.7253029223093371 and parameters: {'booster': 'dart', 'lambda': 0.11662496011340487, 'alpha': 1.436661611535191e-07, 'subsample': 0.9300864121870008, 'colsample_bytree': 0.9807280298407253, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.667597334619932, 'gamma': 7.586935344879682e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0029239159660735896, 'skip_drop': 0.6384572479857079}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:25,063] Trial 186 finished with value: 0.7281539558089808 and parameters: {'booster': 'dart', 'lambda': 0.17767700057396119, 'alpha': 1.012644534959149e-06, 'subsample': 0.9893491508182716, 'colsample_bytree': 0.9087586406995521, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.2602882038019954, 'gamma': 1.603009875769722e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.002015188147112586, 'skip_drop': 0.25512382244836873}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:25,999] Trial 187 finished with value: 0.7281539558089808 and parameters: {'booster': 'dart', 'lambda': 0.046477518074414935, 'alpha': 2.3845755257401193e-07, 'subsample': 0.9084006207444316, 'colsample_bytree': 0.9555350896652858, 'max_depth': 9, 'min_child_weight': 10, 'eta': 0.47551596940506896, 'gamma': 1.2270059334554004e-07, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.004000548066696549, 'skip_drop': 0.4002885747987504}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:27,008] Trial 188 finished with value: 0.7213114754098361 and parameters: {'booster': 'dart', 'lambda': 0.06896961952126578, 'alpha': 1.0755069614910578e-07, 'subsample': 0.9612980997009448, 'colsample_bytree': 0.934006652064489, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.102963636735812, 'gamma': 4.437164047822725e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'forest', 'rate_drop': 0.0010338386531641027, 'skip_drop': 0.15344273289410645}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:27,982] Trial 189 finished with value: 0.7302922309337134 and parameters: {'booster': 'dart', 'lambda': 0.2524312955665969, 'alpha': 8.174852784863357e-07, 'subsample': 0.9506449589358235, 'colsample_bytree': 0.8837167673227777, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.19515353787363945, 'gamma': 3.224600419515336e-08, 'grow_policy': 'lossguide', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.0005219330052391371, 'skip_drop': 0.6683948323434151}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:28,968] Trial 190 finished with value: 0.7325730577334284 and parameters: {'booster': 'dart', 'lambda': 0.2721795541772731, 'alpha': 7.084747426723129e-07, 'subsample': 0.9702146587483191, 'colsample_bytree': 0.8853595178769198, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0.17229055971104112, 'gamma': 3.746123805119704e-05, 'grow_policy': 'depthwise', 'sample_type': 'weighted', 'normalize_type': 'tree', 'rate_drop': 0.00047383157341361165, 'skip_drop': 0.6867835783667315}. Best is trial 86 with value: 0.7348538845331433.
# [I 2022-01-12 05:30:29,945] Trial 191 finished with value: 0.7282965074839629 and parameters: {'booster': 'dart', 'lambda': 0.2792584092544006, 'alpha': 4.808301175116668e-07, 'subsample': 0.9470767162697279, 'colsample_bytree': 0.8821736629767868, 'max_depth': 9, 'min_child_weight': 9, 'eta': 0